# %% [markdown]
# <a href="https://colab.research.google.com/github/akashb1504/Basic-Machine-Learning-Projects/blob/main/Linear_Simple_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
def estimate_coef(x, y):
    n = np.size(x)
    m_x = np.mean(x)
    m_y = np.mean(y)
    SS_xy = n*np.sum(y*x) -(np.sum(x)*np.sum(y))
    SS_xx = n*np.sum(x*x) - (np.sum(x)*np.sum(x))
    m = SS_xy / SS_xx
    c = (np.sum(y) - m*np.sum(x))/n
    return (m,c)

def plot_regression_line(x, y, m, c):
    plt.scatter(x, y, color = "m", marker = "o", s = 30)
    y_pred = m*x+c
    plt.plot(x, y_pred, color = "g")
    plt.xlabel('x')
    plt.ylabel('y')
    plt.show()
if __name__ == "__main__":
    x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
    y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
    m, c = estimate_coef(x, y)
    print(f"Estimated coefficients: Slope and Intercept {m}, {c}")
    plot_regression_line(x, y, m, c)
# Out:
# Estimated coefficients: Slope and Intercept -1.7512877115526122, 103.10596026490066
